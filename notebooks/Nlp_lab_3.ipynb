# %%
import numpy
a=numpy.array([1,2,3])
print(a)
# Out:
# [1 2 3]

# %%
import seaborn
seaborn.scatterplot(x=[1,2,3],y=[4,5,6])
# Out:
# <Axes: >

# %%
seaborn.relational.scatterplot(x=[1,2,3],y=[10,11,12])
# Out:
# <Axes: >

# %%
from seaborn import scatterplot
scatterplot(x=[1,2,3],y=[10,11,12])
# Out:
# <Axes: >

# %%
from seaborn.relational import scatterplot
scatterplot(x=[1,2,3],y=[4,5,6])
# Out:
# <Axes: >
