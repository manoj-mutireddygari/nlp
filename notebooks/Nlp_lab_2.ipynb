# %%
import nltk
import numpy as np
import pandas

# %%
a = np.array([1,2,3])
print(a)
# Out:
# [1 2 3]

# %%
a=np.array([1,2,3])
b=np.linalg.det([[1,2],[3,4]])
c = np.random.rand(2)
print(a,b,c)
# Out:
# [1 2 3] -2.0000000000000004 [0.34155816 0.37434032]

# %%
a=pandas.Series([1,2,3])
print(a)
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
from pandas import Series
a=Series([1,2,3])
print(a)
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64
